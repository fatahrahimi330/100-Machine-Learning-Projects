# %% [markdown]
# ### Credit Card Fraud Detection using RandomForestClassifier in sklearn

# %% [markdown]
# ##### 1. Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from matplotlib import gridspec

# %% [markdown]
# ##### 2. Importing Dataset

# %%
df = pd.read_csv("creditcard.csv")
df.head()
