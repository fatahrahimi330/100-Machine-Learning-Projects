# %% [markdown]
# ### Online Payment Fraud Detection using multiple algorithm in Sklearn.

# %% [markdown]
# ##### 1. Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd

# %% [markdown]
# ##### 2. Loading Dataset

# %%
df = pd.read_csv('new_data.csv')
df.head()

# %% [markdown]
# ##### 3. Preprocessing

# %% [markdown]
# 1. EDA

# %% [markdown]
# 2. Train Test Split

# %% [markdown]
# ##### 4. Build and Train the Models

# %% [markdown]
# ##### 5. Evaluating the Models

# %% [markdown]
# ##### 6. Make Prediction
