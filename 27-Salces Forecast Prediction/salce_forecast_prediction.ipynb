# %% [markdown]
# # Salce Forecast Prediction using XGBRegressor in xgboost

# %% [markdown]
# ### 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Loading Dataset

# %%
# !wget

# %%
df = pd.read_csv('train.csv')
df.head()

# %% [markdown]
# ### 3. Data Preprocessing

# %% [markdown]
# 1. Exploratory Data Analysis

# %% [markdown]
# 2. Feature Engineering

# %% [markdown]
# 3. Train Test Split

# %% [markdown]
# ### 4. Build and Train the Model

# %% [markdown]
# ### 5. Make Prediction

# %% [markdown]
# ### 6. Evaluate the Model
