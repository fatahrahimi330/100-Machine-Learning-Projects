# %% [markdown]
# ## Box Office Revenue Prediction using LinearRegression in Scikit-Learn

# %% [markdown]
# ### 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Loading Dataset

# %%
df = pd.read_csv('')
df.head()

# %% [markdown]
# ### 3. Preprocessing

# %% [markdown]
# 1. Exploratory Data Analysis

# %% [markdown]
# 2. Feature Engineering

# %% [markdown]
# 3. Encoding Feature

# %% [markdown]
# 4. Traing Test Split

# %% [markdown]
# 5. Feature Scaling

# %% [markdown]
# ### 4. Train and Fit the Model

# %% [markdown]
# ### 5. Make Prediction

# %% [markdown]
# ### 6. Evaluate the Model
