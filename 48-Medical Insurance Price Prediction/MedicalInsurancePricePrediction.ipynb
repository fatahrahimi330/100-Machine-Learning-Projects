# %% [markdown]
# ## Medical Insurance Price Prediction using Multiple Algoritms in Sklearn

# %% [markdown]
# ### 1. Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Loading Dataset

# %%
url = ""

# %%
df = pd.read_csv(url)
df.head()

# %% [markdown]
# ### 3. Data Preprocessing

# %% [markdown]
# ### 4. Build and Fit the Models

# %% [markdown]
# ### 5. Make Prediction

# %% [markdown]
# ### 6. Evalate the Models
