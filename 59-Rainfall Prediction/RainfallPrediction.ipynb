# %% [markdown]
# ## Rainfall Prediction using x in y

# %% [markdown]
# ### 1. Importing Dataset

# %% [markdown]
# ### 2. Loading Dataset

# %% [markdown]
# ### 3. Data Preprocessing

# %% [markdown]
# ### 4. Build and Fit the Models

# %% [markdown]
# ### 5. Make Prediction

# %% [markdown]
# ### 6. Evaluate the Models
