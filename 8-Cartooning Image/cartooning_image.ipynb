# %% [markdown]
# ### Cartooning as Image using OpenCV
# Turning a normal Photo to a funny one.

# %% [markdown]
# ##### 1. Importing Libraries

# %%
import cv2

# %% [markdown]
# ##### 2. Importing the Data
